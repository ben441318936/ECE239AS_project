# %% [markdown]
# ## Training

# %%
import gym
import numpy as np

from stable_baselines import TD3
from stable_baselines.td3.policies import LnMlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines.ddpg.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

from stable_baselines.common.callbacks import CheckpointCallback, EvalCallback
from stable_baselines.bench import Monitor

from modules import CustomTD3Policy

import tensorflow as tf
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

from modules import KukaBulletGymFixedBall

import os

# Reloading any code written in external .py files.
# %load_ext autoreload
# %autoreload 2
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# Set the logging and saving directories
parent = "./TD3_kuka_fixed_ball_deep/"
checkpoint_path = parent + "checkpoints/"
best_model_path = parent + "best_model/"
eval_log_path = parent + "eval_logs/"
monitor_log_path = parent + "monitor_logs/"

# %%
# Make environment with monitor wrapper
env = KukaBulletGymFixedBall.KukaBulletGym(render=False)
wrapped_env = Monitor(env, monitor_log_path)

# %%
# Make callbacks
checkpoint_callback = CheckpointCallback(save_freq=50000, 
                                         save_path=checkpoint_path,
                                         name_prefix="model")
eval_callback = EvalCallback(env,
                             best_model_save_path=best_model_path, 
                             log_path=eval_log_path,
                             eval_freq=1000, 
                             deterministic=True, 
                             render=False,
                             verbose=0,
                             n_eval_episodes=50)

# %%
# The noise objects for TD3
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

# %%
model = TD3(CustomTD3Policy.CustomTD3Policy, wrapped_env, action_noise=action_noise, verbose=1)

# %%
model.learn(total_timesteps=int(5e5), log_interval=5000, callback=[checkpoint_callback,eval_callback])
# Out:
# C:\Anaconda\envs\stable_bl\lib\site-packages\stable_baselines\common\callbacks.py:277: UserWarning: Training and eval env are not of the same type<Monitor<KukaBulletGym instance>> != <stable_baselines.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x000002024EE1E808>
#   "{} != {}".format(self.training_env, self.eval_env))
# -----------------------------------------
# | current_lr              | 0.0003      |
# | ep_rewmean              | 0.502       |
# | episodes                | 5000        |
# | eplenmean               | 5.12        |
# | fps                     | 10          |
# | mean 100 episode reward | 0.5         |
# | n_updates               | 29400       |
# | qf1_loss                | 0.027069476 |
# | qf2_loss                | 0.026438512 |
# | time_elapsed            | 2906        |
# | total timesteps         | 29531       |
# -----------------------------------------
# ----------------------------------------
# | current_lr              | 0.0003     |
# | ep_rewmean              | 0.229      |
# | episodes                | 10000      |
# | eplenmean               | 5.02       |
# | fps                     | 10         |
# | mean 100 episode reward | 0.2        |
# | n_updates               | 54100      |
# | qf1_loss                | 0.07146864 |
# | qf2_loss                | 0.07531491 |
# | time_elapsed            | 5321       |
# | total timesteps         | 54258      |
# ----------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 9.71      |
# | episodes                | 15000     |
# | eplenmean               | 5.3       |
# | fps                     | 10        |
# | mean 100 episode reward | 9.7       |
# | n_updates               | 80500     |
# | qf1_loss                | 29.128428 |
# | qf2_loss                | 29.924072 |
# | time_elapsed            | 8012      |
# | total timesteps         | 80629     |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 0.714     |
# | episodes                | 20000     |
# | eplenmean               | 6         |
# | fps                     | 10        |
# | mean 100 episode reward | 0.7       |
# | n_updates               | 107600    |
# | qf1_loss                | 121.77975 |
# | qf2_loss                | 120.69565 |
# | time_elapsed            | 10425     |
# | total timesteps         | 107765    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 26.7      |
# | episodes                | 25000     |
# | eplenmean               | 5.97      |
# | fps                     | 10        |
# | mean 100 episode reward | 26.7      |
# | n_updates               | 136200    |
# | qf1_loss                | 195.95593 |
# | qf2_loss                | 198.05225 |
# | time_elapsed            | 12806     |
# | total timesteps         | 136349    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 6.32      |
# | episodes                | 30000     |
# | eplenmean               | 6         |
# | fps                     | 10        |
# | mean 100 episode reward | 6.3       |
# | n_updates               | 165600    |
# | qf1_loss                | 222.3433  |
# | qf2_loss                | 220.10391 |
# | time_elapsed            | 15203     |
# | total timesteps         | 165742    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 10.6      |
# | episodes                | 35000     |
# | eplenmean               | 5.99      |
# | fps                     | 11        |
# | mean 100 episode reward | 10.6      |
# | n_updates               | 194600    |
# | qf1_loss                | 179.94893 |
# | qf2_loss                | 186.14972 |
# | time_elapsed            | 17572     |
# | total timesteps         | 194761    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 19.6      |
# | episodes                | 40000     |
# | eplenmean               | 5.84      |
# | fps                     | 11        |
# | mean 100 episode reward | 19.6      |
# | n_updates               | 224000    |
# | qf1_loss                | 208.58572 |
# | qf2_loss                | 202.73517 |
# | time_elapsed            | 20002     |
# | total timesteps         | 224170    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 20        |
# | episodes                | 45000     |
# | eplenmean               | 5.66      |
# | fps                     | 11        |
# | mean 100 episode reward | 20        |
# | n_updates               | 253000    |
# | qf1_loss                | 235.53674 |
# | qf2_loss                | 240.78764 |
# | time_elapsed            | 22405     |
# | total timesteps         | 253113    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 20.5      |
# | episodes                | 50000     |
# | eplenmean               | 5.71      |
# | fps                     | 11        |
# | mean 100 episode reward | 20.5      |
# | n_updates               | 281500    |
# | qf1_loss                | 232.98213 |
# | qf2_loss                | 231.15138 |
# | time_elapsed            | 24771     |
# | total timesteps         | 281699    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 18.6      |
# | episodes                | 55000     |
# | eplenmean               | 5.73      |
# | fps                     | 11        |
# | mean 100 episode reward | 18.6      |
# | n_updates               | 310100    |
# | qf1_loss                | 193.21938 |
# | qf2_loss                | 188.46478 |
# | time_elapsed            | 27161     |
# | total timesteps         | 310263    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 24.7      |
# | episodes                | 60000     |
# | eplenmean               | 5.91      |
# | fps                     | 11        |
# | mean 100 episode reward | 24.7      |
# | n_updates               | 339000    |
# | qf1_loss                | 193.39932 |
# | qf2_loss                | 191.1986  |
# | time_elapsed            | 29557     |
# | total timesteps         | 339196    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 17        |
# | episodes                | 65000     |
# | eplenmean               | 5.9       |
# | fps                     | 11        |
# | mean 100 episode reward | 17        |
# | n_updates               | 368500    |
# | qf1_loss                | 203.57776 |
# | qf2_loss                | 183.35756 |
# | time_elapsed            | 31969     |
# | total timesteps         | 368635    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 19.3      |
# | episodes                | 70000     |
# | eplenmean               | 5.93      |
# | fps                     | 11        |
# | mean 100 episode reward | 19.3      |
# | n_updates               | 397900    |
# | qf1_loss                | 194.47124 |
# | qf2_loss                | 201.47232 |
# | time_elapsed            | 34395     |
# | total timesteps         | 398100    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 14.8      |
# | episodes                | 75000     |
# | eplenmean               | 5.83      |
# | fps                     | 11        |
# | mean 100 episode reward | 14.8      |
# | n_updates               | 427400    |
# | qf1_loss                | 206.92018 |
# | qf2_loss                | 185.78943 |
# | time_elapsed            | 36808     |
# | total timesteps         | 427592    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 19.1      |
# | episodes                | 80000     |
# | eplenmean               | 5.86      |
# | fps                     | 11        |
# | mean 100 episode reward | 19.1      |
# | n_updates               | 456700    |
# | qf1_loss                | 201.5759  |
# | qf2_loss                | 194.79044 |
# | time_elapsed            | 39212     |
# | total timesteps         | 456895    |
# ---------------------------------------
# ---------------------------------------
# | current_lr              | 0.0003    |
# | ep_rewmean              | 15.7      |
# | episodes                | 85000     |
# | eplenmean               | 5.8       |
# | fps                     | 11        |
# | mean 100 episode reward | 15.7      |
# | n_updates               | 485800    |
# | qf1_loss                | 190.91582 |
# | qf2_loss                | 191.923   |
# | time_elapsed            | 41610     |
# | total timesteps         | 485932    |
# ---------------------------------------

# %%
model.save(checkpoint_path+"end_manual")
